# %%
import sys
from pathlib import Path

script_dir = Path("../ectuner/utils")
sys.path.insert(0, str(script_dir.resolve()))

# %%
import show_all_tunings as sat

# %%
cart = '/ec/res4/hpcperm/ccff/ecearth4/jobs/'
exps = ['fav9', 'fa7b', 'fa7c', 'fa7d']
df = sat.main(cart, exp_list = exps)
# Out:
# Reading tuning files...
# Reading from exp tuning set
# Found 4 tuning configurations
# Removing empty keys...
#
# Filling missing parameters with defaults...

# %%
colorz = ['orange', 'steelblue', 'indianred', 'forestgreen', 'violet', 'maroon', 'teal', 'black', 'purple', 'olive', 'chocolate', 'dodgerblue', 'rosybrown', 'darkgoldenrod', 'lightseagreen', 'dimgrey', 'midnightblue']

colors = colorz[4:8]

# %%
sat.plot_scatter(df, colors = colors)

# %%
sat.plot_heatmap(df)
